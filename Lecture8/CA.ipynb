# %%
# from Crypto.Util.number import *
# from secret import flag

# p = getPrime(512)
# q = getPrime(512)
# n = p * q
# e = 0x10001
# c = pow(bytes_to_long(flag), e, n)


def digitsSum(n, base):
    ret = 0
    while n:
        ret += n % base
        n //= base
    return ret


# hint = [digitsSum(p, i) for i in range(2, 200)]
#
# print(f"{n = }")
# print(f"{e = }")
# print(f"{c = }")
# print(f"{hint = }")

# %%
ZZ(17).digits(7)
# Out:
# [3, 2]

# %%
n = 
e = 65537
c = 
hint = [
    250,
    305,
    371,
    421,
    519,
    569,
    583,
    621,
    746,
    679,
    787,
    821,
    880,
    919,
    899,
    1021,
    1038,
    1151,
    1133,
    1229,
    1157,
    1205,
    1237,
    1301,
    1399,
    1335,
    1574,
    1549,
    1495,
    1469,
    1564,
    1709,
    1634,
    1633,
    1759,
    1673,
    1794,
    1817,
    1790,
    1989,
    1971,
    2081,
    2058,
    2041,
    2114,
    2065,
    2239,
    2381,
    2193,
    2199,
    2432,
    2297,
    2500,
    2519,
    2459,
    2501,
    2558,
    2597,
    2647,
    2609,
    2750,
    2711,
    2627,
    2765,
    2609,
    3053,
    2931,
    3333,
    2939,
    2809,
    2843,
    2789,
    3002,
    3089,
    2924,
    3185,
    3306,
    3389,
    3169,
    2989,
    3302,
    3201,
    3153,
    3089,
    2874,
    3305,
    3554,
    3493,
    3822,
    3419,
    3467,
    3261,
    3548,
    3461,
    3679,
    3533,
    3420,
    4251,
    4274,
    4249,
    3967,
    4013,
    4172,
    4117,
    3824,
    4461,
    3707,
    4193,
    3585,
    4109,
    4532,
    4237,
    4009,
    4439,
    4089,
    4917,
    3896,
    4181,
    4370,
    3989,
    4032,
    4641,
    4841,
    4509,
    4324,
    4643,
    4379,
    4685,
    4595,
    5079,
    4437,
    5165,
    5161,
    4271,
    5624,
    4557,
    4570,
    4871,
    5191,
    5189,
    4871,
    4689,
    4923,
    5597,
    4859,
    4973,
    5084,
    5457,
    5196,
    5099,
    4855,
    5541,
    5237,
    5077,
    5284,
    5729,
    5468,
    5539,
    5468,
    5709,
    5308,
    5813,
    6201,
    6317,
    5264,
    4979,
    6540,
    5693,
    5885,
    5679,
    5921,
    5713,
    6086,
    6425,
    5574,
    6221,
    5774,
    6581,
    6422,
    6209,
    6324,
    5651,
    6227,
    6021,
    6789,
    6617,
    6155,
    6657,
    6218,
    6719,
    5820,
    6221,
    6026,
    6815,
    6509,
    6113,
    6731,
    7343,
]

# %% [markdown]
# y = a_0 + a_1 * x + a_2 * x^2 + ...
#
# y (mod x - 1) = a_0 + a_1 + ... + a_n (mod x - 1)

# %%
b = lcm(list(range(1, 199)))
b
# Out:
# 1694942657451890777082742546707745765991931571784709719742949858880572955078780854608000

# %%
a = crt(hint, list(range(1, 199)))
b = lcm(list(range(1, 199)))
var('x')
F = Zmod(n)[x]

# p = a + b * K
# a + b * K (mod p * q)


x0 = F(a + x * b).monic().small_roots(X=2**512 // b, beta=0.4)
print(x0)
x0 = int(x0[0])
print(F(a + x * b)(x=x0))

# gcd(F(a + x * b)(x=x0), n)

p = int(a) + int(x0) * int(b)
print(p)
assert p < n

q = n // p
d = pow(e, -1, (p-1)*(q-1))
m = pow(c, d, n)
from Crypto.Util.number import long_to_bytes
print(long_to_bytes(m))
# Out:
# [5784150875484499037995939504927189783710817356645353949424936206149]
# 9803804055996377395661297555407717995193624368848835456840817933945305233475351941214020389861312724202360868756327696595499557783763691215592842447055949
# 9803804055996377395661297555407717995193624368848835456840817933945305233475351941214020389861312724202360868756327696595499557783763691215592842447055949
# b'BALSN{crt_f0r_th3_w1n}'
